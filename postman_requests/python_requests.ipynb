# %% [markdown]
# ### Exploring GitHub API with requests
#
# * Importing packages

# %%
import pandas as pd
import requests
import time

# %% [markdown]
# *  Setting variables

# %%
#Set type of returned data
accept_format = 'application/json'
headers= {'Accept': accept_format}

# %% [markdown]
# * Creating empty dataframe

# %%
#Creates a dictionary containing empty columns to be used to create the pandas
#dataframe
cols =  {'id':[" "],'node_id':[" "], 'avatar_url':[" "], 'gravatar_id':[" "], 'url':[" "], 'html_url':[" "], 'followers_url':[" "], 
        'following_url':[" "],'gists_url':[" "], 'starred_url':[" "], 'subscriptions_url':[" "], 'organizations_url':[" "], 'repos_url':[" "],
        'events_url':[" "], 'received_events_url':[" "],'type':[" "], 'site_admin':[" "]
        }
        
#Creates a pandas dataframe with empty columns that will store the data extracted from 
#API on each call in the 'for' loop
df_ = pd.DataFrame(cols)

# %%
def parse_df(df):
    df = df.iloc[1: , :]
    df = df[['id', 'login','node_id', 'avatar_url', 'gravatar_id', 'url', 'html_url',
           'followers_url', 'following_url', 'gists_url', 'starred_url',
           'subscriptions_url', 'organizations_url', 'repos_url', 'events_url',
           'received_events_url', 'type', 'site_admin', 'login']]
    return df

# %% [markdown]
# * Extracting data from API

# %%
for i in range (0,9,1):
    get_users = requests.get(f'https://api.github.com/users?since= + {i}')
    jsonResponse = get_users.json()
    #Converts jsonresponse to dataframe
    df = pd.DataFrame.from_dict(jsonResponse)
    #Appends data from newly dataframe created that contains the API extraction to new dataframe
    df_ = df_.append(df)
    time.sleep(2)

# %%
df_
# Out:
#     id       node_id                                      avatar_url  \
# 0
# 0    1  MDQ6VXNlcjE=   https://avatars.githubusercontent.com/u/1?v=4
# 1    2  MDQ6VXNlcjI=   https://avatars.githubusercontent.com/u/2?v=4
# 2    3  MDQ6VXNlcjM=   https://avatars.githubusercontent.com/u/3?v=4
# 3    4  MDQ6VXNlcjQ=   https://avatars.githubusercontent.com/u/4?v=4
# ..  ..           ...                                             ...
# 25  49  MDQ6VXNlcjQ5  https://avatars.githubusercontent.com/u/49?v=4
# 26  50  MDQ6VXNlcjUw  https://avatars.githubusercontent.com/u/50?v=4
# 27  51  MDQ6VXNlcjUx  https://avatars.githubusercontent.com/u/51?v=4
# 28  52  MDQ6VXNlcjUy  https://avatars.githubusercontent.com/u/52?v=4
# 29  53  MDQ6VXNlcjUz  https://avatars.githubusercontent.com/u/53?v=4
#
#    gravatar_id                                       url  \
# 0
# 0                   https://api.github.com/users/mojombo
# 1                   https://api.github.com/users/defunkt
# 2                   https://api.github.com/users/pjhyett
# 3                    https://api.github.com/users/wycats
# ..         ...                                       ...
# 25                 https://api.github.com/users/hornbeck
# 26                https://api.github.com/users/jwhitmire
# 27              https://api.github.com/users/elbowdonkey
# 28                    https://api.github.com/users/reinh
# 29                https://api.github.com/users/knzconnor
#
#                           html_url  \
# 0
# 0       https://github.com/mojombo
# 1       https://github.com/defunkt
# 2       https://github.com/pjhyett
# 3        https://github.com/wycats
# ..                             ...
# 25     https://github.com/hornbeck
# 26    https://github.com/jwhitmire
# 27  https://github.com/elbowdonkey
# 28        https://github.com/reinh
# 29    https://github.com/knzconnor
#
#                                         followers_url  \
# 0
# 0      https://api.github.com/users/mojombo/followers
# 1      https://api.github.com/users/defunkt/followers
# 2      https://api.github.com/users/pjhyett/followers
# 3       https://api.github.com/users/wycats/followers
# ..                                                ...
# 25    https://api.github.com/users/hornbeck/followers
# 26   https://api.github.com/users/jwhitmire/followers
# 27  https://api.github.com/users/elbowdonkey/follo...
# 28       https://api.github.com/users/reinh/followers
# 29   https://api.github.com/users/knzconnor/followers
#
#                                         following_url  \
# 0
# 0   https://api.github.com/users/mojombo/following...
# 1   https://api.github.com/users/defunkt/following...
# 2   https://api.github.com/users/pjhyett/following...
# 3   https://api.github.com/users/wycats/following{...
# ..                                                ...
# 25  https://api.github.com/users/hornbeck/followin...
# 26  https://api.github.com/users/jwhitmire/followi...
# 27  https://api.github.com/users/elbowdonkey/follo...
# 28  https://api.github.com/users/reinh/following{/...
# 29  https://api.github.com/users/knzconnor/followi...
#
#                                             gists_url  \
# 0
# 0   https://api.github.com/users/mojombo/gists{/gi...
# 1   https://api.github.com/users/defunkt/gists{/gi...
# 2   https://api.github.com/users/pjhyett/gists{/gi...
# 3   https://api.github.com/users/wycats/gists{/gis...
# ..                                                ...
# 25  https://api.github.com/users/hornbeck/gists{/g...
# 26  https://api.github.com/users/jwhitmire/gists{/...
# 27  https://api.github.com/users/elbowdonkey/gists...
# 28  https://api.github.com/users/reinh/gists{/gist...
# 29  https://api.github.com/users/knzconnor/gists{/...
#
#                                           starred_url  \
# 0
# 0   https://api.github.com/users/mojombo/starred{/...
# 1   https://api.github.com/users/defunkt/starred{/...
# 2   https://api.github.com/users/pjhyett/starred{/...
# 3   https://api.github.com/users/wycats/starred{/o...
# ..                                                ...
# 25  https://api.github.com/users/hornbeck/starred{...
# 26  https://api.github.com/users/jwhitmire/starred...
# 27  https://api.github.com/users/elbowdonkey/starr...
# 28  https://api.github.com/users/reinh/starred{/ow...
# 29  https://api.github.com/users/knzconnor/starred...
#
#                                     subscriptions_url  \
# 0
# 0   https://api.github.com/users/mojombo/subscript...
# 1   https://api.github.com/users/defunkt/subscript...
# 2   https://api.github.com/users/pjhyett/subscript...
# 3   https://api.github.com/users/wycats/subscriptions
# ..                                                ...
# 25  https://api.github.com/users/hornbeck/subscrip...
# 26  https://api.github.com/users/jwhitmire/subscri...
# 27  https://api.github.com/users/elbowdonkey/subsc...
# 28   https://api.github.com/users/reinh/subscriptions
# 29  https://api.github.com/users/knzconnor/subscri...
#
#                                 organizations_url  \
# 0
# 0       https://api.github.com/users/mojombo/orgs
# 1       https://api.github.com/users/defunkt/orgs
# 2       https://api.github.com/users/pjhyett/orgs
# 3        https://api.github.com/users/wycats/orgs
# ..                                            ...
# 25     https://api.github.com/users/hornbeck/orgs
# 26    https://api.github.com/users/jwhitmire/orgs
# 27  https://api.github.com/users/elbowdonkey/orgs
# 28        https://api.github.com/users/reinh/orgs
# 29    https://api.github.com/users/knzconnor/orgs
#
#                                          repos_url  \
# 0
# 0       https://api.github.com/users/mojombo/repos
# 1       https://api.github.com/users/defunkt/repos
# 2       https://api.github.com/users/pjhyett/repos
# 3        https://api.github.com/users/wycats/repos
# ..                                             ...
# 25     https://api.github.com/users/hornbeck/repos
# 26    https://api.github.com/users/jwhitmire/repos
# 27  https://api.github.com/users/elbowdonkey/repos
# 28        https://api.github.com/users/reinh/repos
# 29    https://api.github.com/users/knzconnor/repos
#
#                                            events_url  \
# 0
# 0   https://api.github.com/users/mojombo/events{/p...
# 1   https://api.github.com/users/defunkt/events{/p...
# 2   https://api.github.com/users/pjhyett/events{/p...
# 3   https://api.github.com/users/wycats/events{/pr...
# ..                                                ...
# 25  https://api.github.com/users/hornbeck/events{/...
# 26  https://api.github.com/users/jwhitmire/events{...
# 27  https://api.github.com/users/elbowdonkey/event...
# 28  https://api.github.com/users/reinh/events{/pri...
# 29  https://api.github.com/users/knzconnor/events{...
#
#                                   received_events_url  type site_admin  \
# 0
# 0   https://api.github.com/users/mojombo/received_...  User      False
# 1   https://api.github.com/users/defunkt/received_...  User      False
# 2   https://api.github.com/users/pjhyett/received_...  User      False
# 3   https://api.github.com/users/wycats/received_e...  User      False
# ..                                                ...   ...        ...
# 25  https://api.github.com/users/hornbeck/received...  User      False
# 26  https://api.github.com/users/jwhitmire/receive...  User      False
# 27  https://api.github.com/users/elbowdonkey/recei...  User      False
# 28  https://api.github.com/users/reinh/received_ev...  User      False
# 29  https://api.github.com/users/knzconnor/receive...  User      False
#
#           login
# 0           NaN
# 0       mojombo
# 1       defunkt
# 2       pjhyett
# 3        wycats
# ..          ...
# 25     hornbeck
# 26    jwhitmire
# 27  elbowdonkey
# 28        reinh
# 29    knzconnor
#
# [271 rows x 18 columns]

# %%
df = parse_df(df_)

# %%
df.head(5)
# Out:
#   id     login       node_id                                     avatar_url  \
# 0  1   mojombo  MDQ6VXNlcjE=  https://avatars.githubusercontent.com/u/1?v=4
# 1  2   defunkt  MDQ6VXNlcjI=  https://avatars.githubusercontent.com/u/2?v=4
# 2  3   pjhyett  MDQ6VXNlcjM=  https://avatars.githubusercontent.com/u/3?v=4
# 3  4    wycats  MDQ6VXNlcjQ=  https://avatars.githubusercontent.com/u/4?v=4
# 4  5  ezmobius  MDQ6VXNlcjU=  https://avatars.githubusercontent.com/u/5?v=4
#
#   gravatar_id                                    url  \
# 0               https://api.github.com/users/mojombo
# 1               https://api.github.com/users/defunkt
# 2               https://api.github.com/users/pjhyett
# 3                https://api.github.com/users/wycats
# 4              https://api.github.com/users/ezmobius
#
#                       html_url  \
# 0   https://github.com/mojombo
# 1   https://github.com/defunkt
# 2   https://github.com/pjhyett
# 3    https://github.com/wycats
# 4  https://github.com/ezmobius
#
#                                      followers_url  \
# 0   https://api.github.com/users/mojombo/followers
# 1   https://api.github.com/users/defunkt/followers
# 2   https://api.github.com/users/pjhyett/followers
# 3    https://api.github.com/users/wycats/followers
# 4  https://api.github.com/users/ezmobius/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/mojombo/following...
# 1  https://api.github.com/users/defunkt/following...
# 2  https://api.github.com/users/pjhyett/following...
# 3  https://api.github.com/users/wycats/following{...
# 4  https://api.github.com/users/ezmobius/followin...
#
#                                            gists_url  \
# 0  https://api.github.com/users/mojombo/gists{/gi...
# 1  https://api.github.com/users/defunkt/gists{/gi...
# 2  https://api.github.com/users/pjhyett/gists{/gi...
# 3  https://api.github.com/users/wycats/gists{/gis...
# 4  https://api.github.com/users/ezmobius/gists{/g...
#
#                                          starred_url  \
# 0  https://api.github.com/users/mojombo/starred{/...
# 1  https://api.github.com/users/defunkt/starred{/...
# 2  https://api.github.com/users/pjhyett/starred{/...
# 3  https://api.github.com/users/wycats/starred{/o...
# 4  https://api.github.com/users/ezmobius/starred{...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/mojombo/subscript...
# 1  https://api.github.com/users/defunkt/subscript...
# 2  https://api.github.com/users/pjhyett/subscript...
# 3  https://api.github.com/users/wycats/subscriptions
# 4  https://api.github.com/users/ezmobius/subscrip...
#
#                             organizations_url  \
# 0   https://api.github.com/users/mojombo/orgs
# 1   https://api.github.com/users/defunkt/orgs
# 2   https://api.github.com/users/pjhyett/orgs
# 3    https://api.github.com/users/wycats/orgs
# 4  https://api.github.com/users/ezmobius/orgs
#
#                                      repos_url  \
# 0   https://api.github.com/users/mojombo/repos
# 1   https://api.github.com/users/defunkt/repos
# 2   https://api.github.com/users/pjhyett/repos
# 3    https://api.github.com/users/wycats/repos
# 4  https://api.github.com/users/ezmobius/repos
#
#                                           events_url  \
# 0  https://api.github.com/users/mojombo/events{/p...
# 1  https://api.github.com/users/defunkt/events{/p...
# 2  https://api.github.com/users/pjhyett/events{/p...
# 3  https://api.github.com/users/wycats/events{/pr...
# 4  https://api.github.com/users/ezmobius/events{/...
#
#                                  received_events_url  type site_admin  \
# 0  https://api.github.com/users/mojombo/received_...  User      False
# 1  https://api.github.com/users/defunkt/received_...  User      False
# 2  https://api.github.com/users/pjhyett/received_...  User      False
# 3  https://api.github.com/users/wycats/received_e...  User      False
# 4  https://api.github.com/users/ezmobius/received...  User      False
#
#       login
# 0   mojombo
# 1   defunkt
# 2   pjhyett
# 3    wycats
# 4  ezmobius

# %%
df.columns
# Out:
# Index(['id', 'login', 'node_id', 'avatar_url', 'gravatar_id', 'url',
#        'html_url', 'followers_url', 'following_url', 'gists_url',
#        'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url',
#        'events_url', 'received_events_url', 'type', 'site_admin', 'login'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 270 entries, 0 to 29
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   270 non-null    object
#  1   login                270 non-null    object
#  2   node_id              270 non-null    object
#  3   avatar_url           270 non-null    object
#  4   gravatar_id          270 non-null    object
#  5   url                  270 non-null    object
#  6   html_url             270 non-null    object
#  7   followers_url        270 non-null    object
#  8   following_url        270 non-null    object
#  9   gists_url            270 non-null    object
#  10  starred_url          270 non-null    object
#  11  subscriptions_url    270 non-null    object
#  12  organizations_url    270 non-null    object
#  13  repos_url            270 non-null    object
#  14  events_url           270 non-null    object
#  15  received_events_url  270 non-null    object
#  16  type                 270 non-null    object
#  17  site_admin           270 non-null    object
#  18  login                270 non-null    object
# dtypes: object(19)
# memory usage: 42.2+ KB

# %%
#Changing data type of columns
df["id"] = df["id"].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 270 entries, 0 to 29
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   270 non-null    int64
#  1   login                270 non-null    object
#  2   node_id              270 non-null    object
#  3   avatar_url           270 non-null    object
#  4   gravatar_id          270 non-null    object
#  5   url                  270 non-null    object
#  6   html_url             270 non-null    object
#  7   followers_url        270 non-null    object
#  8   following_url        270 non-null    object
#  9   gists_url            270 non-null    object
#  10  starred_url          270 non-null    object
#  11  subscriptions_url    270 non-null    object
#  12  organizations_url    270 non-null    object
#  13  repos_url            270 non-null    object
#  14  events_url           270 non-null    object
#  15  received_events_url  270 non-null    object
#  16  type                 270 non-null    object
#  17  site_admin           270 non-null    object
#  18  login                270 non-null    object
# dtypes: int64(1), object(18)
# memory usage: 42.2+ KB

# %% [markdown]
# ### Requesting repos info

# %%
my_repos = requests.get(f'https://api.github.com/users/fvgm-spec/repos')
jsonResponse = my_repos.json()
jsonResponse
# Out:
# [{'id': 299914523,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTk5MTQ1MjM=',
#   'name': 'bash',
#   'full_name': 'fvgm-spec/bash',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/bash',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/bash',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/bash/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/bash/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/bash/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/bash/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/bash/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/bash/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/bash/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/bash/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/bash/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/bash/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/bash/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/bash/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/bash/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/bash/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/bash/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/bash/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/bash/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/bash/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/bash/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/bash/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/bash/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/bash/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/bash/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/bash/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/bash/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/bash/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/bash/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/bash/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/bash/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/bash/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/bash/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/bash/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/bash/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/bash/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/bash/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/bash/deployments',
#   'created_at': '2020-09-30T12:39:57Z',
#   'updated_at': '2020-09-30T14:58:50Z',
#   'pushed_at': '2020-09-30T14:58:48Z',
#   'git_url': 'git://github.com/fvgm-spec/bash.git',
#   'ssh_url': 'git@github.com:fvgm-spec/bash.git',
#   'clone_url': 'https://github.com/fvgm-spec/bash.git',
#   'svn_url': 'https://github.com/fvgm-spec/bash',
#   'homepage': None,
#   'size': 1,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Shell',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 381069507,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzODEwNjk1MDc=',
#   'name': 'books',
#   'full_name': 'fvgm-spec/books',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/books',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/books',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/books/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/books/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/books/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/books/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/books/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/books/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/books/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/books/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/books/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/books/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/books/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/books/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/books/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/books/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/books/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/books/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/books/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/books/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/books/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/books/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/books/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/books/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/books/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/books/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/books/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/books/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/books/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/books/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/books/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/books/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/books/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/books/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/books/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/books/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/books/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/books/deployments',
#   'created_at': '2021-06-28T14:57:21Z',
#   'updated_at': '2021-06-28T15:01:34Z',
#   'pushed_at': '2021-06-28T15:01:30Z',
#   'git_url': 'git://github.com/fvgm-spec/books.git',
#   'ssh_url': 'git@github.com:fvgm-spec/books.git',
#   'clone_url': 'https://github.com/fvgm-spec/books.git',
#   'svn_url': 'https://github.com/fvgm-spec/books',
#   'homepage': None,
#   'size': 44190,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 264312823,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjQzMTI4MjM=',
#   'name': 'Codecademy-JS-Projects',
#   'full_name': 'fvgm-spec/Codecademy-JS-Projects',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/Codecademy-JS-Projects',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/Codecademy-JS-Projects/deployments',
#   'created_at': '2020-05-15T22:34:53Z',
#   'updated_at': '2020-05-20T19:11:58Z',
#   'pushed_at': '2020-05-20T19:11:55Z',
#   'git_url': 'git://github.com/fvgm-spec/Codecademy-JS-Projects.git',
#   'ssh_url': 'git@github.com:fvgm-spec/Codecademy-JS-Projects.git',
#   'clone_url': 'https://github.com/fvgm-spec/Codecademy-JS-Projects.git',
#   'svn_url': 'https://github.com/fvgm-spec/Codecademy-JS-Projects',
#   'homepage': None,
#   'size': 136,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 237680984,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzc2ODA5ODQ=',
#   'name': 'csv_files',
#   'full_name': 'fvgm-spec/csv_files',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/csv_files',
#   'description': 'This will host csv_files for Data Science',
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/csv_files',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/csv_files/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/csv_files/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/csv_files/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/csv_files/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/csv_files/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/csv_files/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/csv_files/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/csv_files/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/csv_files/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/csv_files/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/csv_files/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/csv_files/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/csv_files/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/csv_files/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/csv_files/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/csv_files/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/csv_files/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/csv_files/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/csv_files/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/csv_files/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/csv_files/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/csv_files/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/csv_files/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/csv_files/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/csv_files/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/csv_files/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/csv_files/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/csv_files/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/csv_files/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/csv_files/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/csv_files/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/csv_files/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/csv_files/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/csv_files/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/csv_files/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/csv_files/deployments',
#   'created_at': '2020-02-01T21:34:05Z',
#   'updated_at': '2022-06-01T13:50:44Z',
#   'pushed_at': '2022-07-06T22:16:10Z',
#   'git_url': 'git://github.com/fvgm-spec/csv_files.git',
#   'ssh_url': 'git@github.com:fvgm-spec/csv_files.git',
#   'clone_url': 'https://github.com/fvgm-spec/csv_files.git',
#   'svn_url': 'https://github.com/fvgm-spec/csv_files',
#   'homepage': '',
#   'size': 24050,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Shell',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 2,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 2,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'master'},
#  {'id': 267460405,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjc0NjA0MDU=',
#   'name': 'D3',
#   'full_name': 'fvgm-spec/D3',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/D3',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/D3',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/D3/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/D3/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/D3/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/D3/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/D3/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/D3/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/D3/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/D3/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/D3/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/D3/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/D3/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/D3/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/D3/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/D3/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/D3/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/D3/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/D3/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/D3/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/D3/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/D3/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/D3/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/D3/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/D3/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/D3/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/D3/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/D3/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/D3/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/D3/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/D3/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/D3/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/D3/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/D3/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/D3/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/D3/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/D3/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/D3/deployments',
#   'created_at': '2020-05-28T01:05:30Z',
#   'updated_at': '2020-06-06T23:29:31Z',
#   'pushed_at': '2020-06-06T23:29:29Z',
#   'git_url': 'git://github.com/fvgm-spec/D3.git',
#   'ssh_url': 'git@github.com:fvgm-spec/D3.git',
#   'clone_url': 'https://github.com/fvgm-spec/D3.git',
#   'svn_url': 'https://github.com/fvgm-spec/D3',
#   'homepage': None,
#   'size': 232,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 472754746,
#   'node_id': 'R_kgDOHC2qOg',
#   'name': 'data-eng',
#   'full_name': 'fvgm-spec/data-eng',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/data-eng',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/data-eng',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/data-eng/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/data-eng/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/data-eng/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/data-eng/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/data-eng/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/data-eng/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/data-eng/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/data-eng/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/data-eng/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/data-eng/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/data-eng/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/data-eng/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/data-eng/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/data-eng/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/data-eng/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/data-eng/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/data-eng/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/data-eng/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/data-eng/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/data-eng/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/data-eng/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/data-eng/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/data-eng/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/data-eng/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/data-eng/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/data-eng/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/data-eng/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/data-eng/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/data-eng/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/data-eng/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/data-eng/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/data-eng/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/data-eng/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/data-eng/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/data-eng/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/data-eng/deployments',
#   'created_at': '2022-03-22T12:20:18Z',
#   'updated_at': '2022-03-22T12:20:18Z',
#   'pushed_at': '2022-03-22T12:20:19Z',
#   'git_url': 'git://github.com/fvgm-spec/data-eng.git',
#   'ssh_url': 'git@github.com:fvgm-spec/data-eng.git',
#   'clone_url': 'https://github.com/fvgm-spec/data-eng.git',
#   'svn_url': 'https://github.com/fvgm-spec/data-eng',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 341270982,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNDEyNzA5ODI=',
#   'name': 'data_analysis',
#   'full_name': 'fvgm-spec/data_analysis',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/data_analysis',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/data_analysis',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/data_analysis/deployments',
#   'created_at': '2021-02-22T16:52:42Z',
#   'updated_at': '2022-01-07T13:01:53Z',
#   'pushed_at': '2022-06-01T13:23:24Z',
#   'git_url': 'git://github.com/fvgm-spec/data_analysis.git',
#   'ssh_url': 'git@github.com:fvgm-spec/data_analysis.git',
#   'clone_url': 'https://github.com/fvgm-spec/data_analysis.git',
#   'svn_url': 'https://github.com/fvgm-spec/data_analysis',
#   'homepage': None,
#   'size': 1387,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 240382056,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNDAzODIwNTY=',
#   'name': 'Data_Science_Projects',
#   'full_name': 'fvgm-spec/Data_Science_Projects',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/Data_Science_Projects',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/Data_Science_Projects/deployments',
#   'created_at': '2020-02-13T22:43:03Z',
#   'updated_at': '2021-11-26T18:05:49Z',
#   'pushed_at': '2022-06-01T14:01:56Z',
#   'git_url': 'git://github.com/fvgm-spec/Data_Science_Projects.git',
#   'ssh_url': 'git@github.com:fvgm-spec/Data_Science_Projects.git',
#   'clone_url': 'https://github.com/fvgm-spec/Data_Science_Projects.git',
#   'svn_url': 'https://github.com/fvgm-spec/Data_Science_Projects',
#   'homepage': None,
#   'size': 4107,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 340480135,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNDA0ODAxMzU=',
#   'name': 'data_scraper',
#   'full_name': 'fvgm-spec/data_scraper',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/data_scraper',
#   'description': 'Data scraping project',
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/data_scraper',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/data_scraper/deployments',
#   'created_at': '2021-02-19T20:19:36Z',
#   'updated_at': '2021-02-22T00:02:57Z',
#   'pushed_at': '2021-02-22T00:02:56Z',
#   'git_url': 'git://github.com/fvgm-spec/data_scraper.git',
#   'ssh_url': 'git@github.com:fvgm-spec/data_scraper.git',
#   'clone_url': 'https://github.com/fvgm-spec/data_scraper.git',
#   'svn_url': 'https://github.com/fvgm-spec/data_scraper',
#   'homepage': None,
#   'size': 118,
# ...
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/python_automation',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/python_automation',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/python_automation/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/python_automation/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/python_automation/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/python_automation/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/python_automation/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/python_automation/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/python_automation/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/python_automation/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/python_automation/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/python_automation/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/python_automation/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/python_automation/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/python_automation/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/python_automation/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/python_automation/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/python_automation/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/python_automation/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/python_automation/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/python_automation/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/python_automation/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/python_automation/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/python_automation/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/python_automation/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/python_automation/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/python_automation/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/python_automation/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/python_automation/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/python_automation/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/python_automation/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/python_automation/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/python_automation/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/python_automation/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/python_automation/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/python_automation/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/python_automation/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/python_automation/deployments',
#   'created_at': '2020-09-06T20:15:48Z',
#   'updated_at': '2020-09-24T19:19:55Z',
#   'pushed_at': '2020-09-24T19:19:53Z',
#   'git_url': 'git://github.com/fvgm-spec/python_automation.git',
#   'ssh_url': 'git@github.com:fvgm-spec/python_automation.git',
#   'clone_url': 'https://github.com/fvgm-spec/python_automation.git',
#   'svn_url': 'https://github.com/fvgm-spec/python_automation',
#   'homepage': None,
#   'size': 25,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 288015668,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyODgwMTU2Njg=',
#   'name': 'python_repo',
#   'full_name': 'fvgm-spec/python_repo',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/python_repo',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/python_repo',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/python_repo/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/python_repo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/python_repo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/python_repo/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/python_repo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/python_repo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/python_repo/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/python_repo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/python_repo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/python_repo/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/python_repo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/python_repo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/python_repo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/python_repo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/python_repo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/python_repo/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/python_repo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/python_repo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/python_repo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/python_repo/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/python_repo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/python_repo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/python_repo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/python_repo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/python_repo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/python_repo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/python_repo/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/python_repo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/python_repo/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/python_repo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/python_repo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/python_repo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/python_repo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/python_repo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/python_repo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/python_repo/deployments',
#   'created_at': '2020-08-16T20:02:14Z',
#   'updated_at': '2020-08-16T20:16:49Z',
#   'pushed_at': '2020-08-16T20:16:47Z',
#   'git_url': 'git://github.com/fvgm-spec/python_repo.git',
#   'ssh_url': 'git@github.com:fvgm-spec/python_repo.git',
#   'clone_url': 'https://github.com/fvgm-spec/python_repo.git',
#   'svn_url': 'https://github.com/fvgm-spec/python_repo',
#   'homepage': None,
#   'size': 21,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 317841293,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTc4NDEyOTM=',
#   'name': 'Qwiklabs',
#   'full_name': 'fvgm-spec/Qwiklabs',
#   'private': False,
#   'owner': {'login': 'fvgm-spec',
#    'id': 60470663,
#    'node_id': 'MDQ6VXNlcjYwNDcwNjYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60470663?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fvgm-spec',
#    'html_url': 'https://github.com/fvgm-spec',
#    'followers_url': 'https://api.github.com/users/fvgm-spec/followers',
#    'following_url': 'https://api.github.com/users/fvgm-spec/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fvgm-spec/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fvgm-spec/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fvgm-spec/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fvgm-spec/orgs',
#    'repos_url': 'https://api.github.com/users/fvgm-spec/repos',
#    'events_url': 'https://api.github.com/users/fvgm-spec/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fvgm-spec/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/fvgm-spec/Qwiklabs',
#   'description': 'Test repo for Qwiklab practice',
#   'fork': False,
#   'url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs',
#   'forks_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/forks',
#   'keys_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/teams',
#   'hooks_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/events',
#   'assignees_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/tags',
#   'blobs_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/languages',
#   'stargazers_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/subscription',
#   'commits_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/merges',
#   'archive_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/downloads',
#   'issues_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/fvgm-spec/Qwiklabs/deployments',
#   'created_at': '2020-12-02T11:31:28Z',
#   'updated_at': '2020-12-02T11:54:06Z',
#   'pushed_at': '2020-12-02T11:54:04Z',
#   'git_url': 'git://github.com/fvgm-spec/Qwiklabs.git',
#   'ssh_url': 'git@github.com:fvgm-spec/Qwiklabs.git',
#   'clone_url': 'https://github.com/fvgm-spec/Qwiklabs.git',
#   'svn_url': 'https://github.com/fvgm-spec/Qwiklabs',
#   'homepage': None,
#   'size': 3,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'}]
