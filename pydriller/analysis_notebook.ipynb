# %% [markdown]
# ### Extracting data from GitHub repositories using PyDriller
#
# In this notebook we are using [PyDriller framework](https://pydriller.readthedocs.io/en/latest/intro.html) to extract information from GitHub repositories for analytics pusposes. Data from repositories such as commits, developers, modifications, diffs, and source codes, can be quickly and programatically exported to local CSV files or ingested in Cloud storage such as S3.

# %%
import logging
import boto3
import os

import pandas as pd
import duckdb
from pydriller import Repository, Git, Commit

# %% [markdown]
# #### Setting variables

# %%
# Git configurations
REPO_SLUG = "fvgm-spec/my_test_repo"
REPO_URL = f"https://github.com/{REPO_SLUG}.git"
#https://github.com/fvgm-spec/medium_notebooks/my_test_repo.git
# S3 bucket configurations
BUCKET_PATH = f"s3://sample-data9623/github-analytics/{REPO_SLUG}/commits"

# Local path
DATA_PATH = f"output_data"

#Setting connection with DuckDB
conn = duckdb.connect()

# %% [markdown]
# #### Helper functions

# %%
def download_commits(url:str) -> list:
    commits = []
    
    # Traverse the commits in the repository
    for commit in Repository(url).traverse_commits():
        commits.append(
            {
                "commit_hash": commit.hash,
                "commit_msg": commit.msg,
                "author_name": commit.author.name,
                "author_email": commit.author.email,
                "author_date": commit.author_date,
                "author_timezone": commit.author_timezone,
                "merge": commit.merge,
            }
        )

    return commits

def download_modified_files(url:str=REPO_URL) -> list:
    
    modified_files = []

    # Traverse the commits in the repository
    for commit in Repository(url).traverse_commits():

        # Iterate over the modified files in each commit
        for modified_file in commit.modified_files:
            modified_files.append(
                {
                    "commit_hash": commit.hash,
                    "filename": modified_file.filename,
                    "old_path": modified_file.old_path,
                    "new_path": modified_file.new_path,
                    "added_lines": modified_file.added_lines,
                    "deleted_lines": modified_file.deleted_lines,
                }
            )

    return modified_files

def write_commits(commit_list:list,
                  destination:str,
                  filename:str) -> pd.DataFrame:
    
    df = pd.DataFrame(commit_list)
    TIMESTAMP = pd.Timestamp.now().strftime("%Y%m%d%H%M%S")
    df.to_csv(f"{destination}/{filename}_{TIMESTAMP}.csv")

    return df

# %% [markdown]
# #### Git wrapper

# %%
# Creating an instance of the Git wrapper pointing to the path of the local repository
gr = Git(f"D:/dev/fvgm-spec/my_test_repo")
commits = gr.total_commits()
commits
# Out:
# 4

# %% [markdown]
# #### Repository Class and Commit object
#
# **Repository** is the main class of Pydriller, responsible of returning the list of commits you want. One of the main advantage of using PyDriller to mine software repositories is that it is highly configurable. We will now see all the options that once can pass to Repository.
#
# Commit object has all the information of a Git commit, and much more.

# %%
for commit in Repository(REPO_URL).traverse_commits():
    print(
        'The commit {} has been modified by {}, '
        'committed by {} in date {}'.format(
            commit.hash,
            commit.author.name,
            commit.committer.name,
            commit.committer_date
        )
    )
# Out:
# The commit 5ded457557b06e27fd72db8deeefe60e6c4b275d has been modified by Felix Gutierrez, committed by Felix Gutierrez in date 2023-09-06 21:53:09-03:00
# The commit 10c0ab2f500bc07cb47ab165cb91fc592ac85003 has been modified by Felix Gutierrez, committed by Felix Gutierrez in date 2023-09-08 13:52:05-03:00
# The commit b4fc85feca49da95d2d090de7285e7032d9b2680 has been modified by Felix Gutierrez, committed by Felix Gutierrez in date 2023-09-08 13:53:26-03:00
# The commit fca65c2b6c6fd6a8cb45ff391f146f1794eb1cab has been modified by Felix Gutierrez, committed by Felix Gutierrez in date 2023-09-08 13:54:03-03:00

# %% [markdown]
# #### Extracting data from mid-size repo

# %%
#Extracting commits from DuckDB repo
DUCKDB_REPO = 'https://github.com/duckdb/duckdb'
duckdb_commits = download_commits(DUCKDB_REPO)

# %%
#Writing data to CSV file
write_commits(duckdb_commits, DATA_PATH, "duckdb_commits")
# Out:
#                                     commit_hash  \
# 0      ba75d81601913782d28a3878707d135319f38bdd
# 1      82f1559651a20e7a46890ac5127f4d580959f777
# 2      4bbe14a209e1d9db965b0f4f9136993ebb796d92
# 3      3db9596e75b3beaf1e0fe1b48b8847c6e8d3b157
# 4      2b8130d335ab4afef2ae641633fdcf7b5bb0bca6
# ...                                         ...
# 32440  c9c1e16ca16405cab50c4a7b34db9a6ed7abc3ce
# 32441  64936b6658e9fa936f42789379d1510e3e8d2db9
# 32442  20cdfd4c9744c75c0b2f3e4e3d0c29da18bbed89
# 32443  e1503b1647a8b71a61e5fb22656eaad62a24780a
# 32444  d5c4422f728469cc6bb3e41fe1dbf196321fa1f1
#
#                                               commit_msg     author_name  \
# 0            Working parser + initial draft of interface  Mark Raasveldt
# 1      Add partial source tree transformation of SELE...  Mark Raasveldt
# 2           Add namespaces and transform FROM statement.  Mark Raasveldt
# 3      Also properly transform GROUP BY, ORDER BY, LI...  Mark Raasveldt
# 4      Simple catalog definition and hardcoded lineit...  Mark Raasveldt
# ...                                                  ...             ...
# 32440  Extensions autoloading: Add duckdb_aws and fix...  Carlo Piovesan
# 32441                           Bump uncovered_files.csv  Carlo Piovesan
# 32442  Merge pull request #8839 from carlopi/tryautol...            Mark
# 32443  Merge pull request #8826 from szarnyasg/remove...            Mark
# 32444  Merge pull request #8827 from carlopi/duckdb_w...            Mark
#
#                    author_email                author_date  author_timezone  \
# 0      mark.raasveldt@gmail.com  2018-07-13 14:29:24+02:00            -7200
# 1      mark.raasveldt@gmail.com  2018-07-16 16:33:20+02:00            -7200
# 2      mark.raasveldt@gmail.com  2018-07-17 02:01:28+02:00            -7200
# 3      mark.raasveldt@gmail.com  2018-07-17 11:05:26+02:00            -7200
# 4      mark.raasveldt@gmail.com  2018-07-17 16:09:17+02:00            -7200
# ...                         ...                        ...              ...
# 32440  piovesan.carlo@gmail.com  2023-09-07 20:05:24+02:00            -7200
# 32441  piovesan.carlo@gmail.com  2023-09-08 01:32:08+02:00            -7200
# 32442  mark.raasveldt@gmail.com  2023-09-08 11:19:29+02:00            -7200
# 32443  mark.raasveldt@gmail.com  2023-09-08 11:21:12+02:00            -7200
# 32444  mark.raasveldt@gmail.com  2023-09-08 11:21:32+02:00            -7200
#
#        merge
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 32440  False
# 32441  False
# 32442   True
# 32443   True
# 32444   True
#
# [32445 rows x 7 columns]

# %% [markdown]
# #### Querying data with DuckDB

# %%
#Counting the total rows of the dataset
conn.query("""
SELECT COUNT(*)
FROM 'output_data/duckdb_commits_*.csv'
""").fetchall()
# Out:
# [(32445,)]

# %%
#Counting the number of commits per committer
conn.query("""
SELECT author_name,COUNT(commit_hash)
FROM 'output_data/duckdb_commits_*.csv'
GROUP BY author_name""").fetchall()
# Out:
# [('Pedro Holanda', 2320),
#  ('Sam Ansmink', 1254),
#  ('Mark Raasveldt', 8766),
#  ('Tania Bogatsch', 566),
#  ('Tishj', 2635),
#  ('Mark', 3020),
#  ('Richard Wesley', 1797),
#  ('Lindsay Wray', 164),
#  ('satotake', 6),
#  ('Hannes Mühleisen', 2635),
#  ('Elliana May', 519),
#  ('Laurens Kuiper', 2479),
#  ('Josh Wills', 90),
#  ('Max Gabrielsson', 311),
#  ('Tom Ebergen', 318),
#  ('Jacob', 29),
#  ('Koki', 4),
#  ('lokax', 152),
#  ('huangzichun', 3),
#  ('Yves', 45),
#  ('DouEnergy', 82),
#  ('Koki Ueha', 91),
#  ('Nicholas Ursa', 4),
#  ('Tmonster', 166),
#  ('Jens', 62),
#  ('Trent Hauck', 2),
#  ('Jens-H', 22),
#  ('Aleksandr Golubov', 2),
#  ('Will Scullin', 18),
#  ('Carlo Piovesan', 382),
#  ('Mac Lockard', 3),
#  ('stephaniewang', 119),
#  ('ila', 1),
#  ('Yannick Welsch', 14),
#  ('ashish01', 3),
#  ('Eero Lihavainen', 14),
#  ('Pedro Ferreira WX1175653', 62),
#  ('Sebastian Jaenicke', 2),
#  ('Kirill Müller', 358),
#  ('Chang She', 4),
#  ('Jonathan Swenson', 7),
#  ('rmq', 1),
#  ('Chris Brain', 1),
#  ('RJ Atwal', 52),
#  ('Lars Verdoes', 206),
#  ('Lei Xu', 7),
#  ('Alex-Monahan', 6),
#  ('Roland Bouman', 13),
#  ('Roland', 5),
#  ('Anna Neiderud', 1),
#  ('Gregor Karetka', 3),
#  ('Marius Volkhart', 9),
#  ('jacob lacouture', 1),
#  ('Tristan Celder', 35),
#  ('Joey', 3),
#  ('Matthias Möller', 11),
#  ('Wenbo Li', 1),
#  ('csruiliu', 1),
#  ('Jack Drogon', 1),
#  ('Chris Bartak', 1),
#  ('Peter Boncz', 25),
#  ('jniewerth', 3),
#  ('Lindsay', 11),
#  ('Tuyen Nguyen', 63),
#  ('vlowingkloude', 17),
#  ('Reijo Sund', 67),
#  ('Dominik Moritz', 16),
#  ('Damon P. Cortesi', 3),
#  ('Ankur Goyal', 1),
#  ('Phillip Cloud', 14),
#  ('Thomas Powell', 3),
#  ('Denis Hirn', 145),
#  ('Giorgi Dalakishvili', 2),
#  ('Jeroen Ooms', 1),
#  ('pjarra', 7),
#  ('bucweat', 4),
#  ('david-cortes', 1),
#  ('dtenwolde', 18),
#  ('Mark Harrison', 1),
#  ('Erdem Ozdemir', 3),
#  ('ADBond', 14),
#  ('Edwin Zhang', 3),
#  ('Matt Allan', 2),
#  ('Frankie Robertson', 4),
#  ('Ke Xu', 4),
#  ('Dave Murray', 7),
#  ('tania', 13),
#  ('r.4ntix', 4),
#  ('Mark Roddy', 5),
#  ('Mytherin', 23),
#  ('Hannes Muehleisen', 7),
#  ('Alexey Kashuba', 6),
#  ('diegomestre2', 71),
#  ('hannes', 8),
#  ('Hannes', 1),
#  ('Matheus Nerone', 32),
#  ('Arjen P. de Vries', 11),
#  ('aris', 2),
#  ('aris-koning', 26),
#  ('Marc Boeker', 1),
#  ('Sebastian Nehls', 1),
#  ('Uwe L. Korn', 8),
#  ('Philipp Hoch', 5),
#  ('harsha', 10),
#  ('George Kollias', 4),
#  ('mweisgut', 8),
#  ('Guodong Jin', 1),
#  ('Pritam Baral', 2),
#  ('Igor [hyperxor]', 8),
#  ('Chris Brackert', 1),
#  ('James Lamb', 2),
#  ('Andre Kohn', 50),
#  ('Masaki Suketa', 1),
#  ('Iulian-Ioan Birlica', 1),
#  ('Tiago Rodrigo Kepe', 12),
#  ('Tiago Kepe', 666),
#  ('“Mytherin”', 15),
#  ('tdoehmen', 47),
#  ('Phill', 1),
#  ('Erwan Le Pennec', 6),
#  ('Diego Gomes Tome', 122),
#  ('Zhang Jian', 6),
#  ('Diego Gomes Tomé', 1),
#  ('pat-s', 33),
#  ('Manuel Rigger', 1),
#  ('Guilherme Mansur', 4),
#  ('yu tao', 1),
#  ('Johan Dahlin', 1),
#  ('mohamed shazan', 1),
#  ('Naveen Michaud-Agrawal', 5),
#  ('Gabor Szarnyas', 26),
#  ('Eduardo Almeida', 10),
#  ('pacien', 1),
#  ('Gil Forsyth', 11),
#  ('zippond', 46),
#  ('Michael Albers', 7),
#  ('Elliana', 9),
#  ('James Wyles', 2),
#  ('toge', 1),
#  ('Boaz Leskes', 65),
#  ('Dave Hirschfeld', 1),
#  ('Carl Jackson', 6),
#  ('Kimmo Linna', 5),
#  ('wangfenjin', 51),
#  ('Mauro Pagano', 3),
#  ('Hadley Wickham', 8),
#  ('Eero', 2),
#  ('Ila', 3),
#  ('taiyang-li', 1),
#  ('wisp3rwind', 19),
#  ('Philip Moore', 11),
#  ('Administrator', 1),
#  ('lnkuiper', 7),
#  ('Jacob Lacouture', 4),
#  ('Mario Emmenlauer', 3),
#  ('Attila Horvath', 2),
#  ('taofengliu', 6),
#  ('jfb-h', 3),
#  ('Pankaj Pandey', 1),
#  ('zhangwenbin.zwb', 1),
#  ('Nick Robinson', 1),
#  ('kouta-kun', 1),
#  ('NODA Kai', 2),
#  ('Edgar Ramírez Mondragón', 1),
#  ('Steven Lee', 5),
#  ('Antony Courtney', 5),
#  ('Y', 1),
#  ('Lorenzo Moreschini', 1),
#  ('zhouliqi', 8),
#  ('Y. Yang', 2),
#  ('Ian Calvert', 4),
#  ('Liqi Zhou', 2),
#  ('papparapa', 3),
#  ('Jeremiah', 3),
#  ('Ákos Kiss', 1),
#  ('Eivin Hatvik', 2),
#  ('Ubuntu', 1),
#  ('Darren Fu', 2),
#  ('Pedro Ferreira', 15),
#  ('Pedro Pedreira', 5),
#  ('Till Döhmen', 14),
#  ('Evan Jones', 2),
#  ('Andreas Motl', 2),
#  ('Nantia Makrynioti', 34),
#  ('Jesus Anaya Gonzalez', 2),
#  ('Chilarai', 24),
#  ('Baoqi', 3),
#  ('Jake', 1),
#  ('Andrew Kane', 1),
#  ('AzimAfroozeh', 106),
#  ('Andy Teucher', 10),
#  ('Nabil Servais', 1),
#  ('Marco', 2),
#  ('Simon, Reinhard', 37),
#  ('Grant Jenks', 2),
#  ('Edwin de Jonge', 5),
#  ('MonkeybreadSoftware', 1),
#  ('Travis Leith', 7),
#  ('Bermi Ferrer', 1),
#  ('Octavian Sima', 1),
#  ('Mingji Han', 1),
#  ('Paul Leopardi', 4),
#  ('Constantine Peresypkin', 3),
#  ('Wang Fenjin', 1),
#  ('Jonathan Keane', 13),
#  ('tiagokepe', 2),
#  ('Noam Ross', 1),
#  ('snoe925', 1),
#  ('Adrian Ho', 1),
#  ('Phuong LeCong', 17),
#  ('Sutou Kouhei', 1),
#  ('odidev', 1),
#  ('Lawrence Pan', 1),
#  ('Dan Forsberg', 10),
#  ('Alexander Bertram', 1),
#  ('Hajime Morrita', 30),
#  ('Jigao Luo', 13),
#  ('Shannon Noe', 1),
#  ('jacobtolar', 1),
#  ('mwish', 4),
#  ('chenxi8611', 47),
#  ('David Korczynski', 3),
#  ('SartorialOffense', 1),
#  ('Jamie Lentin', 1),
#  ('Stefan Bobev', 3),
#  ('Mark van Raasveldt', 1),
#  ('Xi Chen', 62),
#  ('Binglin Chang', 1),
#  ('hamilton', 3),
#  ('Andre Beckedorf', 3),
#  ('André Kohn', 1),
#  ('Hamilton Ulmer', 2),
#  ('Roope Tikkanen', 1),
#  ('Zhi-peng Dong', 4),
#  ('Aneesh Makala', 13),
#  ('Christian Murphy', 1),
#  ('Nicolas Bennett', 44),
#  ('Jim', 16),
#  ('Jim Stam', 3),
#  ('James Atkins', 2),
#  ('Ryan Kennedy', 2),
#  ('Albert Lesniewski WX1127475', 4),
#  ('Daniël ten Wolde', 1),
#  ('usurai', 20),
#  ('Aryan Naraghi', 2),
#  ('Alan Du', 3),
#  ('Ali', 7),
#  ('Luke Dyer', 1),
#  ('hmb1', 76),
#  ('hongbin', 3),
#  ('metab0t', 4),
#  ('Ben Matasar', 3),
#  ('handstuyennn', 9),
#  ('Aarash Heydari', 1),
#  ('Mohamed', 10),
#  ('Thijs Bruineman', 1),
#  ('Mohamed Elzarei', 1),
#  ('Tom Drabas', 4),
#  ('lykzzzz', 1),
#  ('Maximilian Girlich', 3),
#  ('Tim Nonet', 2),
#  ('Jonathan Lopez', 1),
#  ('drorspei', 1),
#  ('olegel', 5),
#  ('Jarrad Whitaker', 24),
#  ('Orson Peters', 7),
#  ('David Cortes', 2),
#  ('Oleg', 1),
#  ('Jonas Haag', 3),
#  ('Matt Topol', 1),
#  ('Florian Gerlinghoff', 5),
#  ('charlottefelius', 3),
#  ('Maia', 170),
#  ('maiadegraaf', 37),
#  ('Maia de Graaf', 13),
#  ('Andy Prock', 3),
#  ('Arham Chopra', 2),
#  ('Taras Tsugrii', 10),
#  ('Mayank-Baranwal', 2),
#  ('Tania', 2),
#  ('taniabogatsch', 197),
#  ('Elena Felder', 4),
#  ('“taniabogatsch”', 1),
#  ('v1gnesh', 20),
#  ('Nick Gerrets', 92),
#  ('hat', 4),
#  ('Ghassen Hamrouni', 3),
#  ('Angad Nadkarni', 1),
#  ('Adam Davis', 2),
#  ('dawg', 1),
#  ('Nick', 1),
#  ('Henri Nikku', 1),
#  ('Andrei Tudor TOPALĂ (101668)', 1),
#  ('Alexander Chiu', 1),
#  ('Alexander Plavin', 13),
#  ('Lotte Felius', 8),
#  ('Elias James Howell', 1),
#  ('Tyler Beason', 1),
#  ('ccfelius', 7),
#  ('Wang Ji', 1),
#  ('Igor Calabria', 1),
#  ('Virgiel', 1),
#  ('Rob', 1),
#  ('Stephanie Wang', 1),
#  ('Reminiscent', 9),
#  ('Jordi Aranda', 57),
#  ('Jeremy Meulemans', 1),
#  ('Michael Antonov', 1),
#  ('Tanay Tummalapalli', 1),
#  ('Dewey Dunnington', 6),
#  ('Anshul Khandelwal', 2),
#  ('3374614481@qq.com', 1),
#  ('Joey Donovan', 12),
#  ('Matt Holden', 1),
#  ('Indragie Karunaratne', 7),
#  ('Dylan Scott', 3),
#  ('“Tania', 1),
#  ('zhao zhou', 6),
#  ('alnkesq', 5)]

# %% [markdown]
# #### Storing data in S3

# %%
# S3 bucket configurations
REPO_SLUG = "duckdb/duckdb"
BUCKET_PATH = f"s3://sample-data9623/github-analytics/{REPO_SLUG}/commits"

#Writing data to S3 bucket
write_commits(duckdb_commits, BUCKET_PATH, "duckdb_commits")
# Out:
#                                     commit_hash  \
# 0      ba75d81601913782d28a3878707d135319f38bdd
# 1      82f1559651a20e7a46890ac5127f4d580959f777
# 2      4bbe14a209e1d9db965b0f4f9136993ebb796d92
# 3      3db9596e75b3beaf1e0fe1b48b8847c6e8d3b157
# 4      2b8130d335ab4afef2ae641633fdcf7b5bb0bca6
# ...                                         ...
# 32440  c9c1e16ca16405cab50c4a7b34db9a6ed7abc3ce
# 32441  64936b6658e9fa936f42789379d1510e3e8d2db9
# 32442  20cdfd4c9744c75c0b2f3e4e3d0c29da18bbed89
# 32443  e1503b1647a8b71a61e5fb22656eaad62a24780a
# 32444  d5c4422f728469cc6bb3e41fe1dbf196321fa1f1
#
#                                               commit_msg     author_name  \
# 0            Working parser + initial draft of interface  Mark Raasveldt
# 1      Add partial source tree transformation of SELE...  Mark Raasveldt
# 2           Add namespaces and transform FROM statement.  Mark Raasveldt
# 3      Also properly transform GROUP BY, ORDER BY, LI...  Mark Raasveldt
# 4      Simple catalog definition and hardcoded lineit...  Mark Raasveldt
# ...                                                  ...             ...
# 32440  Extensions autoloading: Add duckdb_aws and fix...  Carlo Piovesan
# 32441                           Bump uncovered_files.csv  Carlo Piovesan
# 32442  Merge pull request #8839 from carlopi/tryautol...            Mark
# 32443  Merge pull request #8826 from szarnyasg/remove...            Mark
# 32444  Merge pull request #8827 from carlopi/duckdb_w...            Mark
#
#                    author_email                author_date  author_timezone  \
# 0      mark.raasveldt@gmail.com  2018-07-13 14:29:24+02:00            -7200
# 1      mark.raasveldt@gmail.com  2018-07-16 16:33:20+02:00            -7200
# 2      mark.raasveldt@gmail.com  2018-07-17 02:01:28+02:00            -7200
# 3      mark.raasveldt@gmail.com  2018-07-17 11:05:26+02:00            -7200
# 4      mark.raasveldt@gmail.com  2018-07-17 16:09:17+02:00            -7200
# ...                         ...                        ...              ...
# 32440  piovesan.carlo@gmail.com  2023-09-07 20:05:24+02:00            -7200
# 32441  piovesan.carlo@gmail.com  2023-09-08 01:32:08+02:00            -7200
# 32442  mark.raasveldt@gmail.com  2023-09-08 11:19:29+02:00            -7200
# 32443  mark.raasveldt@gmail.com  2023-09-08 11:21:12+02:00            -7200
# 32444  mark.raasveldt@gmail.com  2023-09-08 11:21:32+02:00            -7200
#
#        merge
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 32440  False
# 32441  False
# 32442   True
# 32443   True
# 32444   True
#
# [32445 rows x 7 columns]
